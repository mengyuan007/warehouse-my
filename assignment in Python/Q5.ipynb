# %% [markdown]
# ## Question 5

# %%
import pandas as pd
import numpy as np
import re
import math
from sklearn.decomposition import TruncatedSVD
from gensim.models import word2vec

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import sys
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.parse.malt import MaltParser
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/mengyuan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mengyuan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mengyuan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mengyuan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# - SVD to obtain word embedding

# %% [markdown]
# (a) Parse the reviews in "200Reviews.csv"

# %%
q5_rd = pd.read_csv("200Reviews.csv")
q5_df = q5_rd.drop(["Unnamed: 0", "id"], axis=1)
# remove <br /> of raw text
q5_df["review"] =  q5_df["review"].apply(lambda x: re.sub("<br />", " ", x))
# sentence segmentation
q5_df["sentence"] = q5_df["review"].apply(lambda x: nltk.sent_tokenize(x))
# word tokenization
q5_df["word"] = q5_df["sentence"].apply(lambda x: [nltk.word_tokenize(x[k]) for k in range(len(x))])
# parts of speech
q5_df["parts_of_speech"] = q5_df["word"].apply(lambda x: [nltk.pos_tag(x[k]) for k in range(len(x))])

# %%
# lemmatization
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''
    
    
def transfer(w):
    wordnettag = get_wordnet_pos(w[1])
    if wordnettag == '':
        lemmatizedword = wordnet_lemmatizer.lemmatize(w[0].lower())
    else:
        lemmatizedword = wordnet_lemmatizer.lemmatize(w[0].lower(),pos=wordnettag)
    if w[0].istitle():
        lemmatizedword = lemmatizedword.capitalize()
    elif w[0].upper()==w[0]:
        lemmatizedword = lemmatizedword.upper()
    else:
        lemmatizedword = lemmatizedword
    return lemmatizedword
    
    
wordnet_lemmatizer = WordNetLemmatizer()

q5_df["lemmatization"] = q5_df["parts_of_speech"].apply(lambda x: [[transfer(w) for w in x[k]] for k in range(len(x))])

# %%
# remove stop word
stopWords = set(stopwords.words('english'))
q5_df["no_stop_word"] = q5_df["lemmatization"].apply(lambda x: [[w for w in x[k] if w.lower() not in stopWords] for k in range(len(x))])
# filter out not alpha
q5_df["no_stop_word_isalpha"] = q5_df["no_stop_word"].apply(lambda x: [[w for w in x[k] if w.isalpha()] for k in range(len(x))])

# %%
q5_df.head()
# Out:
#    sentiment                                             review  \
# 0          1  "With all this stuff going down at the moment ...
# 1          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2          0  "The film starts with a manager (Nicholas Bell...
# 3          0  "It must be assumed that those who praised thi...
# 4          1  "Superbly trashy and wondrously unpretentious ...
#
#                                             sentence  \
# 0  ["With all this stuff going down at the moment...
# 1  ["\"The Classic War of the Worlds\" by Timothy...
# 2  ["The film starts with a manager (Nicholas Bel...
# 3  ["It must be assumed that those who praised th...
# 4  ["Superbly trashy and wondrously unpretentious...
#
#                                                 word  \
# 0  [[``, With, all, this, stuff, going, down, at,...
# 1  [[``, \, '', The, Classic, War, of, the, World...
# 2  [[``, The, film, starts, with, a, manager, (, ...
# 3  [[``, It, must, be, assumed, that, those, who,...
# 4  [[``, Superbly, trashy, and, wondrously, unpre...
#
#                                      parts_of_speech  \
# 0  [[(``, ``), (With, IN), (all, DT), (this, DT),...
# 1  [[(``, ``), (\, NN), ('', ''), (The, DT), (Cla...
# 2  [[(``, ``), (The, DT), (film, NN), (starts, VB...
# 3  [[(``, ``), (It, PRP), (must, MD), (be, VB), (...
# 4  [[(``, ``), (Superbly, RB), (trashy, JJ), (and...
#
#                                        lemmatization  \
# 0  [[``, With, all, this, stuff, go, down, at, th...
# 1  [[``, \, '', The, Classic, War, of, the, World...
# 2  [[``, The, film, start, with, a, manager, (, N...
# 3  [[``, It, must, be, assume, that, those, who, ...
# 4  [[``, Superbly, trashy, and, wondrously, unpre...
#
#                                         no_stop_word  \
# 0  [[``, stuff, go, moment, MJ, 've, start, liste...
# 1  [[``, \, '', Classic, War, Worlds\, '', Timoth...
# 2  [[``, film, start, manager, (, Nicholas, Bell,...
# 3  [[``, must, assume, praise, film, (, \, '', gr...
# 4  [[``, Superbly, trashy, wondrously, unpretenti...
#
#                                 no_stop_word_isalpha
# 0  [[stuff, go, moment, MJ, start, listen, music,...
# 1  [[Classic, War, Timothy, Hines, entertaining, ...
# 2  [[film, start, manager, Nicholas, Bell, give, ...
# 3  [[must, assume, praise, film, great, filmed, o...
# 4  [[Superbly, trashy, wondrously, unpretentious,...

# %% [markdown]
# (b) Create co-occurance matrix for all remaining words

# %%
def co_matix(corpus, unique_word, window_left_right):
    res = np.zeros((len(unique_word), len(unique_word)))
    for i in range(len(corpus)):
        if i - window_left_right < 0:
            for j in range(i + window_left_right):
                if i != j:
                    res[unique_word.index(corpus[i])][unique_word.index(corpus[j])] += 1
        elif i + window_left_right > len(corpus)-1:
            for j in range(i - window_left_right, len(corpus)):
                if i != j:
                    res[unique_word.index(corpus[i])][unique_word.index(corpus[j])] += 1
        else:
            for j in range(i - window_left_right, i + window_left_right):
                if i != j:
                    res[unique_word.index(corpus[i])][unique_word.index(corpus[j])] += 1
    return res

# %%
# get corpus
corpus = []
for i in q5_df["no_stop_word_isalpha"].values:
    for j in i:
        corpus.extend(j)
        
# corpus

# %%
len(corpus)
# Out:
# 22174

# %%
# unique words of corpus
unique_word = list(set(corpus))
# get co-occurance matrix for all remaining words with window size equals to 5
comatrix = co_matix(corpus, unique_word, 5)

# %% [markdown]
# (c) Apply SVD and obtain word embeddings of size 100

# %%
n = 100
svd = TruncatedSVD(n_components=n)
U_sigma_trunc = svd.fit_transform(comatrix)

# %%
U_sigma_trunc.shape
# Out:
# (6309, 100)

# %%
# result very strange if using u[:, [...100]] as word embedding
u, s, vh = np.linalg.svd(comatrix)
u_100 = u[:, [i for i in range(100)]]
print('Word embedding of size 100\n', u[:, [i for i in range(100)]]) # 100-d
print('Variance along multiple dimensions (a.k.a. singular values) are',s)
# Out:
# Word embedding of size 100
#  [[-3.28890728e-03  2.40686586e-03  2.55713093e-03 ... -7.42758964e-03
#   -2.01360065e-02  1.18918214e-02]
#  [-9.34052394e-04 -1.68790609e-03 -1.24143145e-03 ...  8.75562048e-03
#   -7.33235196e-03 -7.66339901e-03]
#  [-1.96255008e-03 -6.03827509e-03  2.73098486e-03 ... -1.25629275e-02
#   -2.27103072e-03 -1.66592747e-02]
#  ...
#  [-1.00509221e-03 -2.37027010e-03 -2.59928759e-03 ...  8.15989654e-03
#    5.03173176e-03  4.34367231e-03]
#  [-2.64913717e-04  1.20950646e-04 -2.61093839e-04 ...  3.29193952e-03
#    2.44940134e-04 -4.64032485e-05]
#  [-7.55955495e-04 -1.08285398e-04 -2.78799052e-03 ... -1.28230287e-03
#    6.16774724e-04 -2.72557732e-03]]
# Variance along multiple dimensions (a.k.a. singular values) are [3.90681189e+02 1.00904670e+02 9.06125119e+01 ... 1.94520435e-03
#  3.20897453e-04 1.93486336e-05]

# %% [markdown]
# - Word2vec to obtain word embedding

# %%
sentences = []
for i in q5_df["no_stop_word_isalpha"].values:
    for j in i:
        sentences.append(j)

# sentences

# %%
# Creating the model and setting values for the various parameters
num_features = 100  # Word vector dimensionality
min_word_count = 1 # Minimum word count
num_workers = 4     # Number of parallel threads
context = 5        # Context window size
downsampling = 1e-3 # (0.001) Downsample setting for frequent words

# Initializing the train model
print("Training model....")
model = word2vec.Word2Vec(sentences,\
                          workers=num_workers,\
                          size=num_features,\
                          min_count=min_word_count,\
                          window=context,
                          sample=downsampling)

# To make the model memory efficient
model.init_sims(replace=True)

# Saving the model for later use. Can be loaded using Word2Vec.load()
model_name = "q5_word2vec"
model_path = f"{model_name}"
model.save(model_path)
print("model saved")
# Out:
# Training model....
# model saved

# %%
model = word2vec.Word2Vec.load(model_path)
model.wv.doesnt_match("there are many average".split())
# Out:
# /Users/mengyuan/opt/anaconda3/envs/oplex/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'many'

# %%
model.wv.vocab
# Out:
# {'stuff': <gensim.models.keyedvectors.Vocab at 0x7f8c8a5be9d0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f8c6627fc10>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f8c6627f690>,
#  'MJ': <gensim.models.keyedvectors.Vocab at 0x7f8c6627f750>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f8c6627f790>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7f8c6627f850>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbb10>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbed0>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbf50>,
#  'documentary': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbc90>,
#  'Wiz': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbc50>,
#  'Moonwalker': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbd90>,
#  'Maybe': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbbd0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbe90>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbcd0>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbf90>,
#  'insight': <gensim.models.keyedvectors.Vocab at 0x7f8c5cabbe50>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a090>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a150>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a1d0>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a250>,
#  'eighty': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a2d0>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a350>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a3d0>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a450>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a4d0>,
#  'guilty': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a550>,
#  'innocent': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a5d0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a650>,
#  'biography': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a6d0>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a750>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a7d0>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a850>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a8d0>,
#  'cinema': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a950>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9a9d0>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9aa50>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9aad0>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9ab50>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9abd0>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9ac50>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9acd0>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9ad50>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9add0>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9ae50>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9aed0>,
#  'Visually': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9af50>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x7f8c8be9afd0>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0090>,
#  'Michael': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0110>,
#  'Jackson': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0190>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0210>,
#  'remotely': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0290>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0310>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0390>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0410>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0490>,
#  'bore': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0510>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0590>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0610>,
#  'egotist': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0690>,
#  'consent': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0710>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0790>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0810>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0890>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0910>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0990>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0a10>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0a90>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0b10>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0b90>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0c10>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0c90>,
#  'exclude': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0d10>,
#  'Smooth': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0d90>,
#  'Criminal': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0e10>,
#  'sequence': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0e90>,
#  'Joe': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0f10>,
#  'Pesci': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea0f90>,
#  'convince': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5050>,
#  'psychopathic': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea50d0>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5150>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea51d0>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5250>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea52d0>,
#  'overhear': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5350>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea53d0>,
#  'Nah': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5450>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea54d0>,
#  'rant': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5550>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea55d0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5650>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea56d0>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5750>,
#  'dunno': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea57d0>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5850>,
#  'Lot': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea58d0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5950>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea59d0>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5a50>,
#  'robot': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5ad0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5b50>,
#  'Speed': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5bd0>,
#  'Demon': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5c50>,
#  'Also': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5cd0>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5d50>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5dd0>,
#  'patience': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5e50>,
#  'saint': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5ed0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5f50>,
#  'kiddy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea5fd0>,
#  'Bad': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9090>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9110>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9190>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9210>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9290>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9310>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9390>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f8c8a24f450>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f8c8a24f050>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x7f8c8a24f110>,
#  'dance': <gensim.models.keyedvectors.Vocab at 0x7f8c5caaf4d0>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f8c5caaf990>,
#  'Bottom': <gensim.models.keyedvectors.Vocab at 0x7f8c61717d10>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea93d0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9450>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea94d0>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9550>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea95d0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9650>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea96d0>,
#  'wholesome': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9750>,
#  'ironically': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea97d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9850>,
#  'buddy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea98d0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9950>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea99d0>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9a50>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9ad0>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9b50>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9bd0>,
#  'Well': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9c50>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9cd0>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9d50>,
#  'hmmm': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9dd0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9e50>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9ed0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9f50>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x7f8c8bea9fd0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead090>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead110>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead190>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead210>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead290>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead310>,
#  'liar': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead390>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead410>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead490>,
#  'Classic': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead510>,
#  'War': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead590>,
#  'Timothy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead610>,
#  'Hines': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead690>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead710>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead790>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead810>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead890>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead910>,
#  'faithfully': <gensim.models.keyedvectors.Vocab at 0x7f8c8bead990>,
#  'recreate': <gensim.models.keyedvectors.Vocab at 0x7f8c8beada10>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x7f8c8beada90>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadb10>,
#  'succeed': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadb90>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadc10>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadc90>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadd10>,
#  'Hollywood': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadd90>,
#  'fare': <gensim.models.keyedvectors.Vocab at 0x7f8c8beade10>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f8c8beade90>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadf10>,
#  'Spielberg': <gensim.models.keyedvectors.Vocab at 0x7f8c8beadf90>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2050>,
#  'Tom': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb20d0>,
#  'Cruise': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2150>,
#  'slight': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb21d0>,
#  'resemblance': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2250>,
#  'Obviously': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb22d0>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2350>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb23d0>,
#  'envision': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2450>,
#  'amateur': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb24d0>,
#  'criticize': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2550>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb25d0>,
#  'Others': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2650>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb26d0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2750>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb27d0>,
#  'entertain': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2850>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb28d0>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2950>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb29d0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2a50>,
#  'faithful': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2ad0>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2b50>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2bd0>,
#  'overlook': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2c50>,
#  'perceive': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2cd0>,
#  'shortcoming': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2d50>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2dd0>,
#  'Nicholas': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2e50>,
#  'Bell': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2ed0>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2f50>,
#  'investor': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb2fd0>,
#  'Robert': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6090>,
#  'Carradine': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6110>,
#  'Primal': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6190>,
#  'Park': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6210>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6290>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6310>,
#  'mutate': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6390>,
#  'primal': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6410>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6490>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6510>,
#  'fossilized': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6590>,
#  'DNA': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6610>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6690>,
#  'resurrect': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6710>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6790>,
#  'fearsome': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6810>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6890>,
#  'Sabretooth': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6910>,
#  'tiger': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6990>,
#  'Smilodon': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6a10>,
#  'Scientific': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6a90>,
#  'ambition': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6b10>,
#  'deadly': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6b90>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6c10>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6c90>,
#  'voltage': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6d10>,
#  'fence': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6d90>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6e10>,
#  'creature': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6e90>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6f10>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7f8c8beb6f90>,
#  'savagely': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc050>,
#  'stalk': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc0d0>,
#  'prey': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc150>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc1d0>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc250>,
#  'tourist': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc2d0>,
#  'youngster': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc350>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc3d0>,
#  'restricted': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc450>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc4d0>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc550>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc5d0>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc650>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc6d0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc750>,
#  'deadlier': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc7d0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc850>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc8d0>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc950>,
#  'Stacy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebc9d0>,
#  'Haiduk': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebca50>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcad0>,
#  'Brian': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcb50>,
#  'Wimmer': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcbd0>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcc50>,
#  'hardly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebccd0>,
#  'carnivorous': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcd50>,
#  'Smilodons': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcdd0>,
#  'Sabretooths': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebce50>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebced0>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcf50>,
#  'astound': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebcfd0>,
#  'terrifyingly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf090>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf110>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf190>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf210>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf290>,
#  'afoul': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf310>,
#  'Furthermore': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf390>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf410>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf490>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf510>,
#  'victim': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf590>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf610>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf690>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf710>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf790>,
#  'gore': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf810>,
#  'beheading': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf890>,
#  'chill': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf910>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebf990>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfa10>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfa90>,
#  'mediocre': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfb10>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfb90>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfc10>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfc90>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfd10>,
#  'stirring': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfd90>,
#  'entertainment': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfe10>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebfe90>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebff10>,
#  'boring': <gensim.models.keyedvectors.Vocab at 0x7f8c8bebff90>,
#  'majority': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3050>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec30d0>,
#  'generator': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3150>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec31d0>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3250>,
#  'lousy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec32d0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3350>,
#  'player': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec33d0>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3450>,
#  'appropriately': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec34d0>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3550>,
#  'vigorously': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec35d0>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3650>,
#  'dodge': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec36d0>,
#  'beast': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3750>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec37d0>,
#  'leap': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3850>,
#  'dangle': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec38d0>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3950>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec39d0>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3a50>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3ad0>,
#  'realistic': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3b50>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3bd0>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3c50>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3cd0>,
#  'James': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3d50>,
#  'R': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3d90>,
#  'Hickox': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3e10>,
#  'Vanessa': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3e90>,
#  'Angel': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3f10>,
#  'David': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec3f90>,
#  'Keith': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9050>,
#  'John': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec90d0>,
#  'Rhys': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9150>,
#  'Davy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec91d0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9250>,
#  'BC': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec92d0>,
#  'Roland': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9350>,
#  'Emmerich': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec93d0>,
#  'Steven': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9450>,
#  'Strait': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec94d0>,
#  'Cliff': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9550>,
#  'Curtis': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec95d0>,
#  'Camilla': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9650>,
#  'Belle': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec96d0>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9750>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec97d0>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9850>,
#  'bloody': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec98d0>,
#  'badly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9950>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec99d0>,
#  'George': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9a50>,
#  'Miller': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9ad0>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9b50>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9bd0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9c50>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9cd0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9d50>,
#  'Australian': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9dd0>,
#  'television': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9e50>,
#  'Tidal': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9ed0>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9f50>,
#  'Journey': <gensim.models.keyedvectors.Vocab at 0x7f8c8bec9fd0>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd090>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd110>,
#  'occasionally': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd190>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd210>,
#  'Snowy': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd290>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd310>,
#  'Zeus': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd390>,
#  'Roxanne': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd410>,
#  'Robinson': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd490>,
#  'Crusoe': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd510>,
#  'Rat': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd590>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd610>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd690>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd710>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd790>,
#  'praise': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd810>,
#  'filmed': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd890>,
#  'opera': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd910>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f8c8becd990>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x7f8c8becda10>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f8c8becda90>,
#  'Wagner': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdb10>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdb90>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdc10>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdc90>,
#  'Cultured': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdd10>,
#  'Either': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdd90>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x7f8c8becde10>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x7f8c8becde90>,
#  'unmitigated': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdf10>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7f8c8becdf90>,
#  'leaden': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2050>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed20d0>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2150>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed21d0>,
#  'tricksy': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2250>,
#  'lugubrious': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed22d0>,
#  'realisation': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2350>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed23d0>,
#  'questionable': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2450>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed24d0>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2550>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed25d0>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2650>,
#  'Shakespeare': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed26d0>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2750>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed27d0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2850>,
#  'theatre': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed28d0>,
#  'studio': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2950>,
#  'Syberberg': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed29d0>,
#  'fashionably': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2a50>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2ad0>,
#  'justification': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2b50>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2bd0>,
#  'Parsifal': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2c50>,
#  'bisexual': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2cd0>,
#  'integration': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2d50>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2dd0>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2e50>,
#  'transmute': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2ed0>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2f50>,
#  'beatnik': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed2fd0>,
#  'babe': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6090>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6110>,
#  'sing': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6190>,
#  'tenor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6210>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6290>,
#  'singer': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6310>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6390>,
#  'dose': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6410>,
#  'Armin': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6490>,
#  'Jordan': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6510>,
#  'conductor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6590>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6610>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6690>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6710>,
#  'Amfortas': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6790>,
#  'monstrously': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6810>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6890>,
#  'Batonzilla': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6910>,
#  'Conductor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6990>,
#  'Ate': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6a10>,
#  'Monsalvat': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6a90>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6b10>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6b90>,
#  'Friday': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6c10>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6c90>,
#  'transcendant': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6d10>,
#  'loveliness': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6d90>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6e10>,
#  'scattering': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6e90>,
#  'shopworn': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6f10>,
#  'flaccid': <gensim.models.keyedvectors.Vocab at 0x7f8c8bed6f90>,
#  'crocus': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a050>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a0d0>,
#  'turf': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a150>,
#  'expedient': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a1d0>,
#  'baffle': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a250>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a2d0>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a350>,
#  'imperfection': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a3d0>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a450>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a4d0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a550>,
#  'splice': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a5d0>,
#  'Gurnemanz': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a650>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a6d0>,
#  'pasture': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a750>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a7d0>,
#  'Julie': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a850>,
#  'Andrew': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a8d0>,
#  'Sound': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a950>,
#  'Music': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4a9d0>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4aa50>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4aad0>,
#  'endure': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ab50>,
#  'trumpet': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4abd0>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ac50>,
#  'possess': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4acd0>,
#  'aural': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ad50>,
#  'glare': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4add0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ae50>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4aed0>,
#  'fatigue': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4af50>,
#  'impatience': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4afd0>,
#  'uninspired': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f090>,
#  'conducting': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f110>,
#  'paralytic': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f190>,
#  'unfolding': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f210>,
#  'ritual': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f290>,
#  'Someone': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f310>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f390>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f410>,
#  'Bayreuth': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f490>,
#  'recording': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f510>,
#  'Knappertsbusch': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f590>,
#  'tempo': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f610>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f690>,
#  'altogether': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f710>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f790>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f810>,
#  'pulse': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f890>,
#  'ebb': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f910>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4f990>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fa10>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fa90>,
#  'orchestral': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fb10>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fb90>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fc10>,
#  'pressing': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fc90>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fd10>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fd90>,
#  'Superbly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fe10>,
#  'trashy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4fe90>,
#  'wondrously': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ff10>,
#  'unpretentious': <gensim.models.keyedvectors.Vocab at 0x7f8c64c4ff90>,
#  'exploitation': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53050>,
#  'hooray': <gensim.models.keyedvectors.Vocab at 0x7f8c64c530d0>,
#  'somewhat': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53150>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7f8c64c531d0>,
#  'impression': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53250>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f8c64c532d0>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53350>,
#  'harrowing': <gensim.models.keyedvectors.Vocab at 0x7f8c64c533d0>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53450>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f8c64c534d0>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53550>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f8c64c535d0>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53650>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f8c64c536d0>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53750>,
#  'nonsensical': <gensim.models.keyedvectors.Vocab at 0x7f8c64c537d0>,
#  'chainsaw': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53850>,
#  'battle': <gensim.models.keyedvectors.Vocab at 0x7f8c64c538d0>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53950>,
#  'lurid': <gensim.models.keyedvectors.Vocab at 0x7f8c64c539d0>,
#  'dialog': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53a50>,
#  'gratuitous': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53ad0>,
#  'nudity': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53b50>,
#  'Bo': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53bd0>,
#  'Ingrid': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53c50>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53cd0>,
#  'orphaned': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53d50>,
#  'sibling': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53dd0>,
#  'unusually': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53e50>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53ed0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53f50>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c53fd0>,
#  'pervert': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57090>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57110>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57190>,
#  'playfully': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57210>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57290>,
#  'towel': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57310>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57390>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57410>,
#  'naked': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57490>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57510>,
#  'stare': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57590>,
#  'unshaven': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57610>,
#  'genitals': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57690>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57710>,
#  'judge': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57790>,
#  'dubbed': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57810>,
#  'laughter': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57890>,
#  'Sick': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57910>,
#  'dude': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57990>,
#  'Anyway': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57a10>,
#  'flee': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57a90>,
#  'Russia': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57b10>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57b90>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57c10>,
#  'soldier': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57c90>,
#  'brutally': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57d10>,
#  'slaughter': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57d90>,
#  'mommy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57e10>,
#  'daddy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57e90>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57f10>,
#  'smuggler': <gensim.models.keyedvectors.Vocab at 0x7f8c64c57f90>,
#  'custody': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d050>,
#  'raise': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d0d0>,
#  'trained': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d150>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d1d0>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d250>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d2d0>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d350>,
#  'quest': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d3d0>,
#  'mythical': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d450>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d4d0>,
#  'valuable': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d550>,
#  'White': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d5d0>,
#  'Fire': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d650>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d6d0>,
#  'coincidentally': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d750>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d7d0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d850>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d8d0>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d950>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5d9d0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5da50>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dad0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5db50>,
#  'clue': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dbd0>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dc50>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dcd0>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dd50>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5ddd0>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5de50>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5ded0>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5df50>,
#  'magnificently': <gensim.models.keyedvectors.Vocab at 0x7f8c64c5dfd0>,
#  'grotesque': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60090>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60110>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60190>,
#  'pleasingly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60210>,
#  'retarded': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60290>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60310>,
#  'bonkers': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60390>,
#  'repair': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60410>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60490>,
#  'wo': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60510>,
#  'reveal': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60590>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60610>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60690>,
#  'Fred': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60710>,
#  'Williamson': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60790>,
#  'cigar': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60810>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60890>,
#  'sleazy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60910>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60990>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60a10>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60a90>,
#  'prostitute': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60b10>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60b90>,
#  'opponent': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60c10>,
#  'Italian': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60c90>,
#  'chick': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60d10>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60d90>,
#  'hideous': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60e10>,
#  'accent': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60e90>,
#  'preposterous': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60f10>,
#  'catchy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c60f90>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66050>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x7f8c64c660d0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66150>,
#  'dozen': <gensim.models.keyedvectors.Vocab at 0x7f8c64c661d0>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66250>,
#  'obligatory': <gensim.models.keyedvectors.Vocab at 0x7f8c64c662d0>,
#  'montage': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66350>,
#  'load': <gensim.models.keyedvectors.Vocab at 0x7f8c64c663d0>,
#  'attraction': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66450>,
#  'God': <gensim.models.keyedvectors.Vocab at 0x7f8c64c664d0>,
#  'brilliant': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66550>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f8c64c665d0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66650>,
#  'French': <gensim.models.keyedvectors.Vocab at 0x7f8c64c666d0>,
#  'translate': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66750>,
#  'Life': <gensim.models.keyedvectors.Vocab at 0x7f8c64c667d0>,
#  'uniquely': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66850>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x7f8c64c668d0>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66950>,
#  'None': <gensim.models.keyedvectors.Vocab at 0x7f8c64c669d0>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66a50>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66ad0>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66b50>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66bd0>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66c50>,
#  'Harry': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66cd0>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66d50>,
#  'Sure': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66dd0>,
#  'offensive': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66e50>,
#  'Eastwood': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66ed0>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66f50>,
#  'Dirty': <gensim.models.keyedvectors.Vocab at 0x7f8c64c66fd0>,
#  'Pat': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a090>,
#  'Hingle': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a110>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a190>,
#  'cop': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a210>,
#  'DIRTY': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a290>,
#  'HARRY': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a310>,
#  'DEAD': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a390>,
#  'POOL': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a410>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a490>,
#  'Cheesy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a510>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a590>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a610>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a690>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a710>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a790>,
#  'evil': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a810>,
#  'Druid': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a890>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a910>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6a990>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6aa10>,
#  'migraine': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6aa90>,
#  'drag': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ab10>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ab90>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ac10>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ac90>,
#  'plod': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ad10>,
#  'Christopher': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ad90>,
#  'Walken': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ae10>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6ae90>,
#  'senseless': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6af10>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6af90>,
#  'TV': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e050>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e0d0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e150>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e1d0>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e250>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e2d0>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e350>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e3d0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e450>,
#  'Capricorn': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e4d0>,
#  'One': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e550>,
#  'clip': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e5d0>,
#  'rocket': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e650>,
#  'relate': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e6d0>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e750>,
#  'Sibrel': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e7d0>,
#  'smoking': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e850>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e8d0>,
#  'astronaut': <gensim.models.keyedvectors.Vocab at 0x7f8c64c6e950>,
# ...
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73450>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f8c64c734d0>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73550>,
#  'grossly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c735d0>,
#  'overprice': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73650>,
#  'Despite': <gensim.models.keyedvectors.Vocab at 0x7f8c64c736d0>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73750>,
#  'Adam': <gensim.models.keyedvectors.Vocab at 0x7f8c64c737d0>,
#  'Sandler': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73850>,
#  'Billy': <gensim.models.keyedvectors.Vocab at 0x7f8c64c738d0>,
#  'Bob': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73950>,
#  'Thornton': <gensim.models.keyedvectors.Vocab at 0x7f8c64c739d0>,
#  'Burt': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73a50>,
#  'Young': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73ad0>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73b50>,
#  'chisel': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73bd0>,
#  'hammer': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73c50>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73cd0>,
#  'earhole': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73d50>,
#  'tire': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73dd0>,
#  'comedic': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73e50>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73ed0>,
#  'consistently': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73f50>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f8c64c73fd0>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77090>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77110>,
#  'audience': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77190>,
#  'seemingly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77210>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77290>,
#  'waiter': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77310>,
#  'cruise': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77390>,
#  'ship': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77410>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77490>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77510>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77590>,
#  'resident': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77610>,
#  'shamelessly': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77690>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77710>,
#  'unfathomable': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77790>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77810>,
#  'opposite': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77890>,
#  'gender': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77910>,
#  'presume': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77990>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77a10>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77a90>,
#  'Shecker': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77b10>,
#  'Dickie': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77b90>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77c10>,
#  'lock': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77c90>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77d10>,
#  'presumably': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77d90>,
#  'Perhaps': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77e10>,
#  'vomit': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77e90>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77f10>,
#  'Like': <gensim.models.keyedvectors.Vocab at 0x7f8c64c77f90>,
#  'Mad': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b050>,
#  'Max': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b0d0>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b150>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b1d0>,
#  'tribute': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b250>,
#  'Peter': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b2d0>,
#  'Lorre': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b350>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b3d0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b450>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b4d0>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b550>,
#  'wetback': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b5d0>,
#  'towelheads': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b650>,
#  'Godless': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b6d0>,
#  'Eastern': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b750>,
#  'European': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b7d0>,
#  'commies': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b850>,
#  'gather': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b8d0>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b950>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7b9d0>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7ba50>,
#  'Gary': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bad0>,
#  'Busey': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bb50>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bbd0>,
#  'butt': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bc50>,
#  'Another': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bcd0>,
#  'laughable': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bd50>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bdd0>,
#  'cultural': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7be50>,
#  'fallout': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bed0>,
#  'Bulletproof': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bf50>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7f8c64c7bfd0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80090>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80110>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80190>,
#  'L': <gensim.models.keyedvectors.Vocab at 0x7f8c64c801d0>,
#  'Q': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80210>,
#  'Jones': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80290>,
#  'Thalmus': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80310>,
#  'Rasulala': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80390>,
#  'Although': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80410>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80490>,
#  'remake': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80510>,
#  'exception': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80590>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80610>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80690>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80710>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80790>,
#  'purely': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80810>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80890>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80910>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80990>,
#  'Capote': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80a10>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80a90>,
#  'Anthony': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80b10>,
#  'Edward': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80b90>,
#  'Eric': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80c10>,
#  'superb': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80c90>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80d10>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80d90>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80e10>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80e90>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80f10>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x7f8c64c80f90>,
#  'certainty': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84050>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f8c64c840d0>,
#  'profession': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84150>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7f8c64c841d0>,
#  'DVD': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84250>,
#  'shelf': <gensim.models.keyedvectors.Vocab at 0x7f8c64c842d0>,
#  'Harvey': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84350>,
#  'Light': <gensim.models.keyedvectors.Vocab at 0x7f8c64c843d0>,
#  'anchor': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84450>,
#  'Spall': <gensim.models.keyedvectors.Vocab at 0x7f8c64c844d0>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84550>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f8c64c845d0>,
#  'morose': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84650>,
#  'tight': <gensim.models.keyedvectors.Vocab at 0x7f8c64c846d0>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84750>,
#  'catharsis': <gensim.models.keyedvectors.Vocab at 0x7f8c64c847d0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84850>,
#  'emotion': <gensim.models.keyedvectors.Vocab at 0x7f8c64c848d0>,
#  'unveiled': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84950>,
#  'surprising': <gensim.models.keyedvectors.Vocab at 0x7f8c64c849d0>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84a50>,
#  'convey': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84ad0>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84b50>,
#  'portray': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84bd0>,
#  'Mike': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84c50>,
#  'Leigh': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84cd0>,
#  'repertory': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84d50>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84dd0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84e50>,
#  'bus': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84ed0>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84f50>,
#  'comic': <gensim.models.keyedvectors.Vocab at 0x7f8c64c84fd0>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda090>,
#  'Simpson': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda110>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda190>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda210>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda290>,
#  'Salisbury': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda310>,
#  'Cathedral': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda390>,
#  'Rhidian': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda410>,
#  'Brook': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda490>,
#  'dramatic': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda510>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda590>,
#  'formally': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda610>,
#  'divide': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda690>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda710>,
#  'introduce': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda790>,
#  'urban': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda810>,
#  'British': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda890>,
#  'racially': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda910>,
#  'religiously': <gensim.models.keyedvectors.Vocab at 0x7f8c8beda990>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedaa10>,
#  'uniform': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedaa90>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedab10>,
#  'rap': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedab90>,
#  'South': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedac10>,
#  'Asian': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedac90>,
#  'Muslim': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedad10>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedad90>,
#  'bully': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedae10>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedae90>,
#  'naturally': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedaf10>,
#  'individually': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedaf90>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede050>,
#  'recognize': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede0d0>,
#  'Shameless': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede150>,
#  'exuberant': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede1d0>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede250>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede2d0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede350>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede3d0>,
#  'Celia': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede450>,
#  'Imrie': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede4d0>,
#  'warmth': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede550>,
#  'supervisor': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede5d0>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede650>,
#  'martinet': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede6d0>,
#  'transformative': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede750>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede7d0>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede850>,
#  'amusingly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede8d0>,
#  'oblivious': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede950>,
#  'Ben': <gensim.models.keyedvectors.Vocab at 0x7f8c8bede9d0>,
#  'Mile': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedea50>,
#  'Coupling': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedead0>,
#  'spoon': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedeb50>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedebd0>,
#  'didactic': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedec50>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedecd0>,
#  'religious': <gensim.models.keyedvectors.Vocab at 0x7f8c8beded50>,
#  'tolerance': <gensim.models.keyedvectors.Vocab at 0x7f8c8bededd0>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedee50>,
#  'BBC': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedeed0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedef50>,
#  'England': <gensim.models.keyedvectors.Vocab at 0x7f8c8bedefd0>,
#  'Easter': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1090>,
#  'America': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1110>,
#  'Christmas': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1190>,
#  'Nathalie': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1210>,
#  'Press': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1290>,
#  'Summer': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1310>,
#  'Love': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1390>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1410>,
#  'redemption': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1490>,
#  'preaching': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1510>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1590>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1610>,
#  'unexpected': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1690>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1710>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1790>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1810>,
#  'interrupt': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1890>,
#  'commercial': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1910>,
#  'pointedly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1990>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1a10>,
#  'pilgrimage': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1a90>,
#  'quiet': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1b10>,
#  'evocation': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1b90>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1c10>,
#  'champagne': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1c90>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1d10>,
#  'repeatedly': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1d90>,
#  'dub': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1e10>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1e90>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f8c8bee1f10>,
#  ...}

# %% [markdown]
# - Compare two methods

# %%
# calculate similarity for SVD
def most_similar_words(word, topn, word_matrix, word_to_id, id_to_word):
    row = word_to_id[word]
    vec = word_matrix[row,:]
    m = word_matrix
    dot_m_v = m.dot(vec.T) # vector
    dot_m_m = np.sum(m * m, axis=1) # vector
    dot_v_v = vec.dot(vec.T) # float
    sims = dot_m_v / (math.sqrt(dot_v_v) * np.sqrt(dot_m_m))
    
    return [(id_to_word[id], round(sims[id],4)) for id in (-sims).argsort()[1:topn+1]]

# %%
# Build unigram <-> index lookup.
word_to_id, id_to_word = {}, {}
for i, x in enumerate(unique_word):
    word_to_id[x] = i
    id_to_word[i] = x

# %%
# comparison between two methods
def compare(word, w2v_model, topn, word_matrix, word_to_id, id_to_word):
    print(f"Most similar words to '{word}':")
    print()
    print("SVD: ", most_similar_words(word, 10, word_matrix, word_to_id, id_to_word))
    print()
    print("Word2Vec: ", [(i, round(j,4)) for i, j in model.wv.most_similar(word)])

# %%
compare("go", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'go':
#
# SVD:  [('one', 0.7156), ('good', 0.7121), ('make', 0.7085), ('see', 0.6987), ('beginning', 0.6966), ('like', 0.6927), ('watch', 0.6863), ('idea', 0.6841), ('bad', 0.6814), ('really', 0.6789)]
#
# Word2Vec:  [('movie', 0.8942), ('one', 0.8888), ('film', 0.8825), ('get', 0.8754), ('scene', 0.8594), ('take', 0.8564), ('like', 0.8554), ('make', 0.8506), ('even', 0.8486), ('character', 0.8463)]

# %%
compare("film", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'film':
#
# SVD:  [('movie', 0.774), ('one', 0.7732), ('good', 0.745), ('bad', 0.742), ('make', 0.7345), ('something', 0.7199), ('understand', 0.7198), ('actually', 0.7191), ('even', 0.7159), ('really', 0.7124)]
#
# Word2Vec:  [('movie', 0.9024), ('go', 0.8825), ('make', 0.8808), ('like', 0.8799), ('scene', 0.8799), ('get', 0.8731), ('one', 0.8729), ('play', 0.8583), ('time', 0.8578), ('actor', 0.8577)]

# %%
compare("actor", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'actor':
#
# SVD:  [('good', 0.6758), ('one', 0.6706), ('make', 0.6686), ('film', 0.6627), ('see', 0.6572), ('movie', 0.6559), ('watch', 0.6542), ('idea', 0.6463), ('bad', 0.6452), ('really', 0.6441)]
#
# Word2Vec:  [('film', 0.8577), ('go', 0.8431), ('first', 0.835), ('movie', 0.8342), ('scene', 0.8253), ('one', 0.817), ('take', 0.8119), ('make', 0.8109), ('much', 0.8084), ('get', 0.8079)]

# %%
compare("character", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'character':
#
# SVD:  [('one', 0.6141), ('story', 0.6141), ('film', 0.6027), ('like', 0.5901), ('see', 0.5842), ('mean', 0.5836), ('write', 0.5751), ('never', 0.5745), ('really', 0.5739), ('make', 0.573)]
#
# Word2Vec:  [('get', 0.8582), ('much', 0.8535), ('go', 0.8463), ('like', 0.8425), ('way', 0.8294), ('take', 0.8277), ('give', 0.8276), ('look', 0.8272), ('play', 0.8262), ('movie', 0.8245)]

# %%
compare("love", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'love':
#
# SVD:  [('fall', 0.6341), ('truly', 0.6212), ('home', 0.6034), ('highly', 0.5986), ('one', 0.5967), ('many', 0.5876), ('One', 0.587), ('whole', 0.5855), ('movie', 0.5793), ('away', 0.5762)]
#
# Word2Vec:  [('movie', 0.802), ('film', 0.7951), ('scene', 0.7766), ('go', 0.7361), ('actor', 0.734), ('like', 0.728), ('get', 0.7257), ('make', 0.7196), ('seem', 0.7172), ('people', 0.7168)]

# %%
compare("story", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'story':
#
# SVD:  [('write', 0.7389), ('film', 0.7005), ('stupid', 0.6551), ('overall', 0.6535), ('one', 0.6521), ('make', 0.6489), ('song', 0.6447), ('understand', 0.6349), ('see', 0.63), ('may', 0.6293)]
#
# Word2Vec:  [('take', 0.7848), ('movie', 0.7773), ('one', 0.7772), ('film', 0.7694), ('get', 0.7632), ('play', 0.7629), ('go', 0.7607), ('come', 0.7547), ('character', 0.7527), ('way', 0.7473)]

# %%
compare("good", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'good':
#
# SVD:  [('bad', 0.8227), ('make', 0.8078), ('movie', 0.7922), ('one', 0.7799), ('definitely', 0.7726), ('watch', 0.7718), ('see', 0.7716), ('thing', 0.7712), ('overall', 0.7706), ('really', 0.7685)]
#
# Word2Vec:  [('film', 0.8374), ('give', 0.8294), ('movie', 0.8107), ('make', 0.8107), ('even', 0.8035), ('like', 0.8023), ('first', 0.7998), ('go', 0.7988), ('try', 0.798), ('play', 0.797)]

# %%
compare("happy", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'happy':
#
# SVD:  [('pacing', 0.7168), ('Man', 0.6879), ('sale', 0.6829), ('MERK', 0.6769), ('research', 0.6709), ('history', 0.6648), ('Moon', 0.6537), ('Branagh', 0.6533), ('Try', 0.651), ('video', 0.6502)]
#
# Word2Vec:  [('Wrestlemania', 0.3519), ('depressive', 0.3431), ('sparse', 0.3208), ('inexplicable', 0.3197), ('channel', 0.3153), ('Ulli', 0.3044), ('joint', 0.2995), ('Amuse', 0.2988), ('flee', 0.2972), ('unexplained', 0.2862)]

# %%
compare("Man", model, 10, U_sigma_trunc, word_to_id, id_to_word)
# Out:
# Most similar words to 'Man':
#
# SVD:  [('see', 0.7756), ('favorite', 0.7608), ('watch', 0.7506), ('must', 0.7409), ('Moon', 0.7404), ('superior', 0.7351), ('far', 0.731), ('among', 0.7255), ('numerous', 0.7207), ('five', 0.7195)]
#
# Word2Vec:  [('defeat', 0.3451), ('CID', 0.3369), ('wit', 0.3296), ('Rather', 0.324), ('male', 0.3233), ('futuristic', 0.319), ('enter', 0.3147), ('exact', 0.3086), ('people', 0.3072), ('bring', 0.3043)]

# %%
# using u from linalg.svd
compare("film", model, 10, u_100, word_to_id, id_to_word)
# Out:
# Most similar words to 'film':
#
# SVD:  [('Thelma', 0.1579), ('Louise', 0.1561), ('Expressionist', 0.151), ('Josef', 0.1486), ('roller', 0.1386), ('Werching', 0.133), ('Office', 0.13), ('Dalmations', 0.1295), ('Hickox', 0.1148), ('commend', 0.1142)]
#
# Word2Vec:  [('movie', 0.9143), ('go', 0.8918), ('make', 0.8886), ('one', 0.8848), ('character', 0.8837), ('get', 0.8757), ('actor', 0.8722), ('take', 0.8712), ('time', 0.8706), ('scene', 0.8678)]
